# %% [markdown]
# **Task 4- Develop A Neural Network That Can Read Handwriting**

# %% [markdown]
# **Importing Libraries**

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras import layers, models

# %% [markdown]
# **Load the dataset**

# %%
(X_train,y_train),(X_test,y_test)=mnist.load_data()

# %% [markdown]
# **Visualize the dataset**

# %%
print("X_train: "+str(X_train.shape))
print("y_train: "+str(y_train.shape))
print("X_test: "+str(X_test.shape))

# %% [markdown]
# The training and test dataset contains 60,000 images and 10,000 images respetively where each is 28x28 pixel greyscale image.

# %%
X_train[0]

# %% [markdown]
# **Plotting few images**

# %%
for i in range(9):
   plt.subplot(330+1+i)
   plt.imshow(X_train[i], cmap=plt.get_cmap('gray'))
plt.show()

# %% [markdown]
# **Reshape the data**

# %%
X_train=X_train.reshape(-1,28,28,1)

# %%
X_test=X_test.reshape(-1,28,28,1)

# %% [markdown]
# **Normalizing the data**

# %%
#pixel value ranges from 0 to 255 for each of the channels RGB 
#divide it by 255 to normalize it to 0 to 1
X_train = X_train / 255
X_test = X_test / 255

# %%
X_train

# %%
#Visualising the data after normalization
for i in range(9):
  plt.subplot(330 + 1 + i)
  plt.imshow(np.squeeze(X_train[i]), cmap=plt.get_cmap('gray'))
plt.show()

# %%
image_shape = X_train.shape[1:]
print(image_shape)

# %% [markdown]
# **Model building**

# %%
model = models.Sequential([
      layers.Conv2D(filters=48, kernel_size=(3,3), activation='relu', input_shape=(28,28,1)),
      layers.MaxPooling2D((2,2)),

      layers.Conv2D(filters=64, kernel_size=(3,3), activation=('relu')),
      layers.MaxPooling2D((2,2)),
      layers.Dropout(0.5),
      layers.Flatten(),
      layers.Dense(256, activation='relu'),
      layers.Dense(10, activation='softmax')
])

# %%
model.compile(optimizer='adam',
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

# %%
model.fit(X_train, y_train, epochs=10)

# %%
model.summary()

# %%
from tensorflow.keras.utils import plot_model
plot_model(model, show_shapes = True)

# %% [markdown]
# **Prediction**

# %%
y_pred=model.predict(X_test)
y_pred[:5]

# %%
plt.imshow(X_test[50], cmap = plt.get_cmap('binary'))

# %%
print("The prediction is : ", np.argmax(y_pred[50]))

# %%
print("The prediction is : ", np.argmax(y_pred[5678]))
